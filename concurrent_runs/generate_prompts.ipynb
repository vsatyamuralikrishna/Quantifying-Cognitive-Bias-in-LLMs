# %%
# %pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 8.4 MB/s  0:00:018.6 MB/s eta 0:00:01:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 8.2 MB/s  0:00:008.3 MB/s eta 0:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]━━━━ 1/2 [pandas]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
import os

# %%
import os
import json
import pandas as pd

# Where to store generated prompts
PROMPT_DIR = "./prompts"
os.makedirs(PROMPT_DIR, exist_ok=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 import os
#       2 import json
# ----> 3 import pandas as pd
#       5 # Where to store generated prompts
#       6 PROMPT_DIR = "./prompts"
#
# ModuleNotFoundError: No module named 'pandas'
